# %%
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = """
machine learning
data visualization
Python
data visualization
statistics
geo analytics

interactive visualizations
data science
scraping websites
Kaggle
Machine learning
Machine Learning
bayesian inference
predictive analytics 
Absolute exponential autocorrelation model
Predictive behaviour
scikit-learn
imputations
model validation
decision trees
pandas
visualization
modeling
Relational Modeling
data visualization
regression models
data visualization
Enough to get to the point I can teach myself more about a wide range of data science topics
Regression
Algorithms
supervised vs unsupervised data
modeling
satellite imaging
recursion
models
python data science packages
quantum realism
machine learning 
Bayes Decision Boundary
predictive analysis
predictive analytics
finding, accessing, and cleaning online datasets
neural nets
web scraping
analyzing open source gov data
Decision Trees
natural language processing
Support Vector Machines
regression
deep learning
random forest
network analysis
social media
Vapnik–Chervonenkis dimension
machine learning
machine learning
NPL
Scraping APIs
command line
deep learning
data visualization
collaborative data science
collaborative data science
collaborative data science
pull requests
predictions
content recommendations best applications
Cleaning data
Pink Elephants
data collection
How to make cookies
sklearn
text analytics

R?
sentiment analysis
understanding the landscape of different tools
"""

# %%
responses = text.lower().split("\n")[1:-1]
phrases = [reduce(lambda a,b: a+"_"+b,phrase.split(" ")) for phrase in responses]
wordcloud = WordCloud().generate(reduce(lambda a,b: a+" "+b,phrases))
# Out:
# /home/keegan/anaconda2/lib/python2.7/site-packages/PIL/ImageDraw.py:104: UserWarning: setfont() is deprecated. Please set the attribute directly instead.
#   "Please set the attribute directly instead.")

# %%
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Rescale for relative counts

# %%
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(reduce(lambda a,b: a+" "+b,phrases))
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
